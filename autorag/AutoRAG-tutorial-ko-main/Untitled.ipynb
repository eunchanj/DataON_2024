# %%
# !pwd
# Out:
# /mnt/workspace/MyFiles/autorag/AutoRAG-tutorial-ko-main

# %%
# !python make_corpus.py
# Out:
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_kwargs" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
import pandas as pd

corpus = pd.read_parquet("data/corpus_new.parquet")
corpus
# Out:
#                                    doc_id  \
# 0    8a0df89f-809d-479d-8e61-d0d1ef7c7825
# 1    6bbc5bac-4998-4909-88e8-29854371ff58
# 2    d83c0d91-4a10-4888-a4e0-30fb2cf2d20d
# 3    aeb814d6-8346-4e2c-b2c7-c6101fc85799
# 4    0ccc52c0-35e2-451a-b942-49712dcaeb49
# ..                                    ...
# 426  aa5168eb-e078-4f77-a25f-ed4e9046f24a
# 427  5050d77b-38e7-4648-9e9e-66c691a194eb
# 428  9d4f2395-fce8-4f4c-b391-fda3ee94f192
# 429  64b5ce61-6b4d-4359-bc6b-be5b43065797
# 430  e995716b-0e64-4e72-8582-59eb0d1668c6
#
#                                               contents  \
# 0    Disease Name: 갑상선기능저하증(Hypothyroidism)\nAnimal...
# 1    : CD)에 의한 누액 분비의 감소- 두부 외상에 의한 누선 또는 그 지배신경의 손...
# 2    Disease Name: 고양이 전염성 복막염(Feline infectious pe...
# 3    상자를 자주 교체해 주지 않는 경우    - 자주 집을 떠나 여행하게 되는 경우  ...
# 4    사료중에 존재하는 Nocardia asteroides에 의한 감염증으로 피하와 내장...
# ..                                                 ...
# 426  Disease Name: 개에서의 질소회로 관련 효소의 결핍 (Urea cycle ...
# ...

# %%
# !python make_qa.py

# %%
qa = pd.read_parquet("data/qa_new.parquet")
qa

# %%
# !pwd
# Out:
# /mnt/workspace/MyFiles/autorag/AutoRAG-tutorial-ko-main

# %%
corpus = pd.read_csv("data/corpus_do.csv")
qa = pd.read_csv("data/qa_do.csv")

# %%
corpus.to_parquet("data/corpus.parquet")
qa.to_parquet("data/qa.parquet")

# %%
# !autorag evaluate --qa_data_path ./data/qa.parquet --corpus_data_path ./data/corpus.parquet --config ./config/tutorial_ko.yaml --project_dir ./benchmark
# Out:
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_kwargs" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# ...

# %%
# !python3 main.py --config ./config/tutorial_ko.yaml
# Out:
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_id" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# /home/eunchan93/miniconda3/envs/eun/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_kwargs" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# ...
